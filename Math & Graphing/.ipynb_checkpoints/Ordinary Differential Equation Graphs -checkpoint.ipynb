# %%
#import necessary modules
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt

# %%
#create function with variables x,y and return partial derivative of y respective to x 
def model(x,y):
    
    dy = (np.e**(-x))/(1+x**2) - (2*x*y)/(1+x**2)
    
    return dy

def model1(x,y):
    
    dy = (x**2)/(1+y**2)
    
    return dy

# %%
#Create a list of initial conditions 
y0_list = [-1,1,0, -0.5]
y0_list = sorted(y0_list)
#Create array of 200 points of equal distance in [0, 20]
x = np.linspace(-1,1,100)
#Get result from odeint function 
result = odeint(model1,y0_list,x)
# Out:
# C:\Users\hanjo\Anaconda3\envs\GPU\lib\site-packages\scipy\integrate\odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %%
#Create a plot
fig,ax = plt.subplots()

for i in range(len(y0_list)):
    
    ax.plot(t,result[:,i],label=f'y{i}={y0_list[i]}')
    
ax.legend()
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.title(f'Integral Curves')
# Out:
# Text(0.5, 1.0, 'Integral Curves')

# %%
#Upper bounds and lower bounds of y and x 
xu = 1
xl = -1
yu = 1
yl = -1

#spacing in between points
s = 0.1

#Spacing between graph and field
b = 1.2

#Create a mesh grid
x,y = np.meshgrid(np.arange(xl,xu,s),np.arange(yl,yu,s))

#dx = 1
dx = np.ones(y.shape)
#dy is 
dy = model1(x,y)

#plot the graph
plt.quiver(x,y,dx,dy, color = 'white')
plt.xlim(xl*b,xu*b)
plt.ylim(yl*b,yu*b)
plt.title(f'Direction field')
plt.show()
